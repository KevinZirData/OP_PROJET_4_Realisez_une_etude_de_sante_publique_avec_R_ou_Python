# %%
# Importation de nos différentes structures pour commencer nos différentes analyses

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
# Importation des données

# %%
aide_alimentaire = pd.read_csv('aide_alimentaire.csv')
sous_nutrition = pd.read_csv('sous_nutrition.csv')
dispo_alimentaire = pd.read_csv('dispo_alimentaire.csv')
population = pd.read_csv('population.csv')

# %% [markdown]
# # Description des Données

# %%
# Nous allons maintenant voir le type de données que nous avons et leur type
# Grâce à la fonction .head() nous allons pouvoir vérifier nos données sous formes de tableaux pour les 5 premières lignes
# On vérifie le type de donnée sur lesquelles nous allons travailler

# %% [markdown]
# # Aide alimentaire

# %%
aide_alimentaire.info()

aide_alimentaire.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1475 entries, 0 to 1474
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Pays bénéficiaire  1475 non-null   object
#  1   Année              1475 non-null   int64
#  2   Produit            1475 non-null   object
#  3   Valeur             1475 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 46.2+ KB
# (1475, 4)

# %%
aide_alimentaire.head(10)
# Out:
#   Pays bénéficiaire  Année                   Produit  Valeur
# 0       Afghanistan   2013       Autres non-céréales     682
# 1       Afghanistan   2014       Autres non-céréales     335
# 2       Afghanistan   2013              Blé et Farin   39224
# 3       Afghanistan   2014              Blé et Farin   15160
# 4       Afghanistan   2013                  Céréales   40504
# 5       Afghanistan   2014                  Céréales   15989
# 6       Afghanistan   2013        Fruits secs, total      85
# 7       Afghanistan   2013          Huiles végétales   11087
# 8       Afghanistan   2014          Huiles végétales    8185
# 9       Afghanistan   2013  Légumineuses Sèches,Tot.   11761

# %% [markdown]
# # Sous_nutrition

# %%
sous_nutrition.info()

sous_nutrition.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1218 entries, 0 to 1217
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Zone    1218 non-null   object
#  1   Année   1218 non-null   object
#  2   Valeur  624 non-null    object
# dtypes: object(3)
# memory usage: 28.7+ KB
# (1218, 3)

# %%
sous_nutrition.head(10)
# Out:
#              Zone      Année Valeur
# 0     Afghanistan  2012-2014    8.6
# 1     Afghanistan  2013-2015    8.8
# 2     Afghanistan  2014-2016    8.9
# 3     Afghanistan  2015-2017    9.7
# 4     Afghanistan  2016-2018   10.5
# 5     Afghanistan  2017-2019   11.1
# 6  Afrique du Sud  2012-2014    2.2
# 7  Afrique du Sud  2013-2015    2.5
# 8  Afrique du Sud  2014-2016    2.8
# 9  Afrique du Sud  2015-2017      3

# %% [markdown]
# # Dispo_alimentaire

# %%
dispo_alimentaire.info()

dispo_alimentaire.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15605 entries, 0 to 15604
# Data columns (total 18 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   Zone                                                           15605 non-null  object
#  1   Produit                                                        15605 non-null  object
#  2   Origine                                                        15605 non-null  object
#  3   Aliments pour animaux                                          2720 non-null   float64
#  4   Autres Utilisations                                            5496 non-null   float64
#  5   Disponibilité alimentaire (Kcal/personne/jour)                 14241 non-null  float64
#  6   Disponibilité alimentaire en quantité (kg/personne/an)         14015 non-null  float64
# ...

# %%
# On peut voir apparaître des valeur Nan
dispo_alimentaire.head(10)
# Out:
#           Zone                Produit   Origine  Aliments pour animaux  \
# 0  Afghanistan       Abats Comestible   animale                    NaN
# 1  Afghanistan        Agrumes, Autres  vegetale                    NaN
# 2  Afghanistan  Aliments pour enfants  vegetale                    NaN
# 3  Afghanistan                 Ananas  vegetale                    NaN
# 4  Afghanistan                Bananes  vegetale                    NaN
# 5  Afghanistan           Beurre, Ghee   animale                    NaN
# 6  Afghanistan                  Bière  vegetale                    NaN
# 7  Afghanistan                    Blé  vegetale                    NaN
# 8  Afghanistan   Boissons Alcooliques  vegetale                    NaN
# 9  Afghanistan                   Café  vegetale                    NaN
#
#    Autres Utilisations  Disponibilité alimentaire (Kcal/personne/jour)  \
# 0                  NaN                                             5.0
# ...

# %% [markdown]
# # Population

# %%
population.info()

population.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1416 entries, 0 to 1415
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Zone    1416 non-null   object
#  1   Année   1416 non-null   int64
#  2   Valeur  1416 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 33.3+ KB
# (1416, 3)

# %%
population.head(10)
# Out:
#              Zone  Année     Valeur
# 0     Afghanistan   2013  32269.589
# 1     Afghanistan   2014  33370.794
# 2     Afghanistan   2015  34413.603
# 3     Afghanistan   2016  35383.032
# 4     Afghanistan   2017  36296.113
# 5     Afghanistan   2018  37171.921
# 6  Afrique du Sud   2013  53687.121
# 7  Afrique du Sud   2014  54544.186
# 8  Afrique du Sud   2015  55386.367
# 9  Afrique du Sud   2016  56207.646

# %% [markdown]
# # Demande de Marc et de Julien

# %% [markdown]
# # I) Proportion de personnes en état de sous-nutrition 2017

# %%
# Nous choisissons maintenant les deux fichiers dont nous allons nous servir pour résoudre cette problématique

# %%
population.head()
# Out:
#           Zone  Année     Valeur
# 0  Afghanistan   2013  32269.589
# 1  Afghanistan   2014  33370.794
# 2  Afghanistan   2015  34413.603
# 3  Afghanistan   2016  35383.032
# 4  Afghanistan   2017  36296.113

# %%
sous_nutrition.head()
# Out:
#           Zone      Année Valeur
# 0  Afghanistan  2012-2014    8.6
# 1  Afghanistan  2013-2015    8.8
# 2  Afghanistan  2014-2016    8.9
# 3  Afghanistan  2015-2017    9.7
# 4  Afghanistan  2016-2018   10.5

# %%
# Pour calculer la proportion demandée nous devons déjà centrer nos données sur 2017
sous_nutrition_2017 = sous_nutrition.loc[sous_nutrition['Année']=='2016-2018']
population_2017 = population.loc[population['Année']== 2017]

# %%
sous_nutrition_2017.head()
# Out:
#               Zone      Année Valeur
# 4      Afghanistan  2016-2018   10.5
# 10  Afrique du Sud  2016-2018    3.1
# 16         Albanie  2016-2018    0.1
# 22         Algérie  2016-2018    1.3
# 28       Allemagne  2016-2018    NaN

# %%
### On vérifie une première fois nos valeurs NaN afin de les retirer pour pouvoir continuer nos calculs
sous_nutrition_2017=sous_nutrition_2017.fillna(0)
sous_nutrition_2017
# Out:
#                                         Zone      Année Valeur
# 4                                Afghanistan  2016-2018   10.5
# 10                            Afrique du Sud  2016-2018    3.1
# 16                                   Albanie  2016-2018    0.1
# 22                                   Algérie  2016-2018    1.3
# 28                                 Allemagne  2016-2018      0
# ...                                      ...        ...    ...
# 1192  Venezuela (République bolivarienne du)  2016-2018      8
# 1198                                Viet Nam  2016-2018    6.5
# 1204                                   Yémen  2016-2018      0
# 1210                                  Zambie  2016-2018      0
# 1216                                Zimbabwe  2016-2018      0
#
# [203 rows x 3 columns]

# %%
# On renomme notre colonne pour avoir plus de lisibilité
sous_nutrition_2017 = sous_nutrition_2017.rename(columns={"Valeur":"Population_sous_nourries"})

# %%
sous_nutrition_2017.dtypes
# Out:
# Zone                        object
# Année                       object
# Population_sous_nourries    object
# dtype: object

# %%
population_2017=population_2017.rename(columns={'Valeur':'Population'})
population_2017.head()
# Out:
#               Zone  Année  Population
# 4      Afghanistan   2017   36296.113
# 10  Afrique du Sud   2017   57009.756
# 16         Albanie   2017    2884.169
# 22         Algérie   2017   41389.189
# 28       Allemagne   2017   82658.409

# %%
population_2017.dtypes
# Out:
# Zone           object
# Année           int64
# Population    float64
# dtype: object

# %%
# Pour que nous puissions continuer dans notre raisonnement il faut faire passser nos données de poulation_sous_nourries en Float
# La fonction pd.to_numeric permet grâce à errors='coerce' d'ignorer les Nan ou les valeurs <0,1

sous_nutrition_2017.Population_sous_nourries=pd.to_numeric(sous_nutrition_2017.Population_sous_nourries, errors = 'coerce')

# %%
sous_nutrition_2017.dtypes
# Out:
# Zone                         object
# Année                        object
# Population_sous_nourries    float64
# dtype: object

# %%
population_2017.head()
# Out:
#               Zone  Année  Population
# 4      Afghanistan   2017   36296.113
# 10  Afrique du Sud   2017   57009.756
# 16         Albanie   2017    2884.169
# 22         Algérie   2017   41389.189
# 28       Allemagne   2017   82658.409

# %%
# On va ensuite faire une jointure sur nos deux dataframe que nous avons obtenues pour 2017
différence_2017= pd.merge(population_2017,sous_nutrition_2017, how='inner',on=['Zone','Zone'])

# %%
print(différence_2017)
# Out:
#                                        Zone  Année_x  Population    Année_y  \
# 0                               Afghanistan     2017   36296.113  2016-2018
# 1                            Afrique du Sud     2017   57009.756  2016-2018
# 2                                   Albanie     2017    2884.169  2016-2018
# 3                                   Algérie     2017   41389.189  2016-2018
# 4                                 Allemagne     2017   82658.409  2016-2018
# ..                                      ...      ...         ...        ...
# 198  Venezuela (République bolivarienne du)     2017   29402.484  2016-2018
# 199                                Viet Nam     2017   94600.648  2016-2018
# 200                                   Yémen     2017   27834.819  2016-2018
# 201                                  Zambie     2017   16853.599  2016-2018
# 202                                Zimbabwe     2017   14236.595  2016-2018
#
#      Population_sous_nourries
# ...

# %%
# On renomme nos colonnes pour la lisibilité
différence_2017 = différence_2017.rename(columns = {'Année_x':'Année'})

# %%
# on supprime la colonne dont on a pas besoin
différence_2017=différence_2017.drop(columns='Année_y')

# %%
# Il faut maintenant mettre la population au même niveau car exprimé en millier
différence_2017['Population']=round((différence_2017['Population']/1000),1)

# %%
différence_2017
# Out:
#                                        Zone  Année  Population  \
# 0                               Afghanistan   2017        36.3
# 1                            Afrique du Sud   2017        57.0
# 2                                   Albanie   2017         2.9
# 3                                   Algérie   2017        41.4
# 4                                 Allemagne   2017        82.7
# ..                                      ...    ...         ...
# 198  Venezuela (République bolivarienne du)   2017        29.4
# 199                                Viet Nam   2017        94.6
# 200                                   Yémen   2017        27.8
# 201                                  Zambie   2017        16.9
# 202                                Zimbabwe   2017        14.2
#
#      Population_sous_nourries
# 0                        10.5
# 1                         3.1
# 2                         0.1
# 3                         1.3
# 4                         0.0
# ...

# %%
# On peut à présent calculer la Proportion
proportion_2017= round((différence_2017['Population_sous_nourries']/différence_2017['Population']*100),2)

# %%
différence_2017['proportion_2017'] = proportion_2017

# %%
différence_2017
# Out:
#                                        Zone  Année  Population  \
# 0                               Afghanistan   2017        36.3
# 1                            Afrique du Sud   2017        57.0
# 2                                   Albanie   2017         2.9
# 3                                   Algérie   2017        41.4
# 4                                 Allemagne   2017        82.7
# ..                                      ...    ...         ...
# 198  Venezuela (République bolivarienne du)   2017        29.4
# 199                                Viet Nam   2017        94.6
# 200                                   Yémen   2017        27.8
# 201                                  Zambie   2017        16.9
# 202                                Zimbabwe   2017        14.2
#
#      Population_sous_nourries  proportion_2017
# 0                        10.5            28.93
# 1                         3.1             5.44
# 2                         0.1             3.45
# ...

# %%
# Nous pouvons voir qu'il y a des valeurs qui apparaissent en NaN encore,
# il faut donc les mettre de côté afin d'obtenir ce qui nous interesse

différence_2017=différence_2017.fillna(0)
différence_2017
# Out:
#                                        Zone  Année  Population  \
# 0                               Afghanistan   2017        36.3
# 1                            Afrique du Sud   2017        57.0
# 2                                   Albanie   2017         2.9
# 3                                   Algérie   2017        41.4
# 4                                 Allemagne   2017        82.7
# ..                                      ...    ...         ...
# 198  Venezuela (République bolivarienne du)   2017        29.4
# 199                                Viet Nam   2017        94.6
# 200                                   Yémen   2017        27.8
# 201                                  Zambie   2017        16.9
# 202                                Zimbabwe   2017        14.2
#
#      Population_sous_nourries  proportion_2017
# 0                        10.5            28.93
# 1                         3.1             5.44
# 2                         0.1             3.45
# ...

# %%
# On peut maintenant calculer les totaux afin de pouvoir calculer la représentation de la population en sous nutrition sur le totale

somme_population= différence_2017['Population'].sum()
somme_population_sous_nourries= différence_2017['Population_sous_nourries'].sum()
pourcentage_sous_nutrition=round((somme_population_sous_nourries/somme_population),1)*100

# %%
somme_population
# Out:
# 7543.9

# %%
print('La population totale est de',somme_population,"millions d'habitants parmis lesquelles",somme_population_sous_nourries,'millions sont en état de  sous-nutrition, ce qui représente',pourcentage_sous_nutrition,'% de la population mondiale ')
# Out:
# La population totale est de 7543.9 millions d'habitants parmis lesquelles 535.7 millions sont en état de  sous-nutrition, ce qui représente 10.0 % de la population mondiale

# %%
# Nous pouvons ranger nos données par rapport à la colonnes population_sous_nourries afin d'obtenir un classement

différence_2017=différence_2017.sort_values(by= 'Population_sous_nourries',ascending= False,ignore_index=True)
différence_2017.head(10)
# Out:
#                                          Zone  Année  Population  \
# 0                                        Inde   2017      1338.7
# 1                                    Pakistan   2017       207.9
# 2                                   Indonésie   2017       264.7
# 3                                     Nigéria   2017       190.9
# 4                                  Bangladesh   2017       159.7
# 5                                    Éthiopie   2017       106.4
# 6                                 Philippines   2017       105.2
# 7                 République-Unie de Tanzanie   2017        54.7
# 8  République populaire démocratique de Corée   2017        25.4
# 9                                       Kenya   2017        50.2
#
#    Population_sous_nourries  proportion_2017
# 0                     190.1            14.20
# 1                      24.8            11.93
# 2                      23.6             8.92
# 3                      22.8            11.94
# ...

# %% [markdown]
# # II)Nombre théorique de personnes qui pourraient être nourries

# %%
 dispo_alimentaire.info()
dispo_alimentaire.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15605 entries, 0 to 15604
# Data columns (total 18 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   Zone                                                           15605 non-null  object
#  1   Produit                                                        15605 non-null  object
#  2   Origine                                                        15605 non-null  object
#  3   Aliments pour animaux                                          2720 non-null   float64
#  4   Autres Utilisations                                            5496 non-null   float64
#  5   Disponibilité alimentaire (Kcal/personne/jour)                 14241 non-null  float64
#  6   Disponibilité alimentaire en quantité (kg/personne/an)         14015 non-null  float64
# ...

# %%
population_2017.info()
population_2017.head(10)
population_2017
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 236 entries, 4 to 1414
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Zone        236 non-null    object
#  1   Année       236 non-null    int64
#  2   Population  236 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 7.4+ KB
#                                         Zone  Année  Population
# 4                                Afghanistan   2017   36296.113
# 10                            Afrique du Sud   2017   57009.756
# 16                                   Albanie   2017    2884.169
# 22                                   Algérie   2017   41389.189
# 28                                 Allemagne   2017   82658.409
# ...                                      ...    ...         ...
# 1390  Venezuela (République bolivarienne du)   2017   29402.484
# 1396                                Viet Nam   2017   94600.648
# ...

# %%
# Il faut maintenant épurer notre dataframe afin d'avoir les éléments qui nous interesse

dispo_alimentaire_affiné=dispo_alimentaire[['Zone','Produit','Disponibilité alimentaire (Kcal/personne/jour)']]

# %%
dispo_alimentaire_affiné.head(10)
# Out:
#           Zone                Produit  \
# 0  Afghanistan       Abats Comestible
# 1  Afghanistan        Agrumes, Autres
# 2  Afghanistan  Aliments pour enfants
# 3  Afghanistan                 Ananas
# 4  Afghanistan                Bananes
# 5  Afghanistan           Beurre, Ghee
# 6  Afghanistan                  Bière
# 7  Afghanistan                    Blé
# 8  Afghanistan   Boissons Alcooliques
# 9  Afghanistan                   Café
#
#    Disponibilité alimentaire (Kcal/personne/jour)
# 0                                             5.0
# 1                                             1.0
# 2                                             1.0
# 3                                             0.0
# 4                                             4.0
# 5                                            23.0
# 6                                             0.0
# 7                                          1369.0
# 8                                             0.0
# ...

# %%
# On va ensuite aggreger les données afin d'avoir un dataframe plus lisible et par pays

table_dispo= pd.pivot_table(dispo_alimentaire_affiné,index='Zone',aggfunc='sum')
table_dispo
# Out:
# C:\Users\33682\AppData\Local\Temp\ipykernel_14812\765636852.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   table_dispo= pd.pivot_table(dispo_alimentaire_affiné,index='Zone',aggfunc='sum')
#                        Disponibilité alimentaire (Kcal/personne/jour)
# Zone
# Afghanistan                                                    2087.0
# Afrique du Sud                                                 3020.0
# Albanie                                                        3188.0
# Algérie                                                        3293.0
# Allemagne                                                      3503.0
# ...                                                               ...
# Émirats arabes unis                                            3275.0
# ...

# %%
# Nous allons maintenant assembler nos 2 dataframes
dispo_2017=pd.merge(population_2017,table_dispo, on='Zone' ,how='inner')

# %%
# on modifie le nom 

dispo_2017=dispo_2017.rename(columns={'Valeur':'Population'})
dispo_2017
# Out:
#                                        Zone  Année  Population  \
# 0                               Afghanistan   2017   36296.113
# 1                            Afrique du Sud   2017   57009.756
# 2                                   Albanie   2017    2884.169
# 3                                   Algérie   2017   41389.189
# 4                                 Allemagne   2017   82658.409
# ..                                      ...    ...         ...
# 167  Venezuela (République bolivarienne du)   2017   29402.484
# 168                                Viet Nam   2017   94600.648
# 169                                   Yémen   2017   27834.819
# 170                                  Zambie   2017   16853.599
# 171                                Zimbabwe   2017   14236.595
#
#      Disponibilité alimentaire (Kcal/personne/jour)
# 0                                            2087.0
# 1                                            3020.0
# ...

# %%
# Il faut ensuite remettre le niveau de la population à l'échelle (million)
dispo_2017['Population']=round((dispo_2017['Population']*1000),1)
dispo_2017
# Out:
#                                        Zone  Année  Population  \
# 0                               Afghanistan   2017  36296113.0
# 1                            Afrique du Sud   2017  57009756.0
# 2                                   Albanie   2017   2884169.0
# 3                                   Algérie   2017  41389189.0
# 4                                 Allemagne   2017  82658409.0
# ..                                      ...    ...         ...
# 167  Venezuela (République bolivarienne du)   2017  29402484.0
# 168                                Viet Nam   2017  94600648.0
# 169                                   Yémen   2017  27834819.0
# 170                                  Zambie   2017  16853599.0
# 171                                Zimbabwe   2017  14236595.0
#
#      Disponibilité alimentaire (Kcal/personne/jour)
# 0                                            2087.0
# 1                                            3020.0
# ...

# %%
# On calcul la disponibilité en fonction de la population

dispo_pays= (dispo_2017['Population']*dispo_2017['Disponibilité alimentaire (Kcal/personne/jour)'])
dispo_pays
# Out:
# 0      7.574999e+10
# 1      1.721695e+11
# 2      9.194731e+09
# 3      1.362946e+11
# 4      2.895524e+11
#            ...
# 167    7.741674e+10
# 168    2.595842e+11
# 169    6.170979e+10
# 170    3.242632e+10
# 171    3.008193e+10
# Length: 172, dtype: float64

# %%
# on rajoute à notre dataset notre nouvelle donnée
dispo_2017['dispo_pays']=dispo_pays
dispo_2017
# Out:
#                                        Zone  Année  Population  \
# 0                               Afghanistan   2017  36296113.0
# 1                            Afrique du Sud   2017  57009756.0
# 2                                   Albanie   2017   2884169.0
# 3                                   Algérie   2017  41389189.0
# 4                                 Allemagne   2017  82658409.0
# ..                                      ...    ...         ...
# 167  Venezuela (République bolivarienne du)   2017  29402484.0
# 168                                Viet Nam   2017  94600648.0
# 169                                   Yémen   2017  27834819.0
# 170                                  Zambie   2017  16853599.0
# 171                                Zimbabwe   2017  14236595.0
#
#      Disponibilité alimentaire (Kcal/personne/jour)    dispo_pays
# 0                                            2087.0  7.574999e+10
# 1                                            3020.0  1.721695e+11
# ...

# %%
# Pour les hommes, le besoin énergétique moyen se situe entre 2400 et 2700 kcal. Pour les femmes, la recommandation est de 2000 à 2400 kcal, nous allons donc partir sur un minimum de 2300 (source Google)
Population_totale=(dispo_2017['Population']).sum()
kcal_totale=(dispo_2017['dispo_pays']).sum()
kcal_min=2300
population_nourrie=round((kcal_totale/kcal_min),1)

# %%
### On peut maintenant calculé la proportion de la population qu'il est possible de nourrir sur 
Proportion_personne_nourrie=round((population_nourrie/Population_totale)*100,2)
Proportion_personne_nourrie
# Out:
# 124.73

# %%
print('il y a',population_nourrie,'personnes qui peuvent être nourrie sur une base de',kcal_min,'kcal par personne et par jours soit',Proportion_personne_nourrie,'% qui pourraient être nourries dans le monde avec une répartition équitable')
# Out:
# il y a 9095210707.5 personnes qui peuvent être nourrie sur une base de 2300 kcal par personne et par jours soit 124.73 % qui pourraient être nourries dans le monde avec une répartition équitable

# %% [markdown]
# # III) Disponibilité alimentaire des produits végétaux

# %%
# On filtre nos données sur notre data
dispo_2=dispo_alimentaire[['Zone','Produit','Origine','Disponibilité alimentaire (Kcal/personne/jour)']]
dispo_2
# Out:
#                Zone                Produit   Origine  \
# 0       Afghanistan       Abats Comestible   animale
# 1       Afghanistan        Agrumes, Autres  vegetale
# 2       Afghanistan  Aliments pour enfants  vegetale
# 3       Afghanistan                 Ananas  vegetale
# 4       Afghanistan                Bananes  vegetale
# ...             ...                    ...       ...
# 15600  Îles Salomon       Viande de Suides   animale
# 15601  Îles Salomon    Viande de Volailles   animale
# 15602  Îles Salomon          Viande, Autre   animale
# 15603  Îles Salomon                    Vin  vegetale
# 15604  Îles Salomon         Épices, Autres  vegetale
#
#        Disponibilité alimentaire (Kcal/personne/jour)
# 0                                                 5.0
# 1                                                 1.0
# 2                                                 1.0
# 3                                                 0.0
# ...

# %%
### Il faut ensuite isoler les produits d'origines végétale
dispo_alimentaire_végétaux=dispo_2.loc[dispo_2['Origine']=='vegetale']
dispo_alimentaire_végétaux
# Out:
#                Zone                Produit   Origine  \
# 1       Afghanistan        Agrumes, Autres  vegetale
# 2       Afghanistan  Aliments pour enfants  vegetale
# 3       Afghanistan                 Ananas  vegetale
# 4       Afghanistan                Bananes  vegetale
# 6       Afghanistan                  Bière  vegetale
# ...             ...                    ...       ...
# 15595  Îles Salomon                 Sésame  vegetale
# 15596  Îles Salomon                    Thé  vegetale
# 15597  Îles Salomon                Tomates  vegetale
# 15603  Îles Salomon                    Vin  vegetale
# 15604  Îles Salomon         Épices, Autres  vegetale
#
#        Disponibilité alimentaire (Kcal/personne/jour)
# 1                                                 1.0
# 2                                                 1.0
# 3                                                 0.0
# 4                                                 4.0
# ...

# %%
# On aggrege nos données grâce au 'groupby'
table_végétaux=dispo_alimentaire_végétaux.groupby(['Zone','Origine'])['Disponibilité alimentaire (Kcal/personne/jour)'].sum()
table_végétaux
# Out:
# Zone                   Origine
# Afghanistan            vegetale    1871.0
# Afrique du Sud         vegetale    2533.0
# Albanie                vegetale    2203.0
# Algérie                vegetale    2915.0
# Allemagne              vegetale    2461.0
#                                     ...
# Émirats arabes unis    vegetale    2718.0
# Équateur               vegetale    1732.0
# États-Unis d'Amérique  vegetale    2698.0
# Éthiopie               vegetale    2005.0
# Îles Salomon           vegetale    2187.0
# Name: Disponibilité alimentaire (Kcal/personne/jour), Length: 174, dtype: float64

# %%
# Nous pouvons faire une jointure entre nos 2 dataframes
Dispo_végétale= pd.merge(population_2017,table_végétaux,on='Zone',how='inner')
Dispo_végétale
# Out:
#                                        Zone  Année  Population  \
# 0                               Afghanistan   2017   36296.113
# 1                            Afrique du Sud   2017   57009.756
# 2                                   Albanie   2017    2884.169
# 3                                   Algérie   2017   41389.189
# 4                                 Allemagne   2017   82658.409
# ..                                      ...    ...         ...
# 167  Venezuela (République bolivarienne du)   2017   29402.484
# 168                                Viet Nam   2017   94600.648
# 169                                   Yémen   2017   27834.819
# 170                                  Zambie   2017   16853.599
# 171                                Zimbabwe   2017   14236.595
#
#      Disponibilité alimentaire (Kcal/personne/jour)
# 0                                            1871.0
# 1                                            2533.0
# ...

# %%
Dispo_végétale.rename(columns={'Valeur':'Population'},inplace=True)

# %%
Dispo_végétale.head(10)
# Out:
#                  Zone  Année  Population  \
# 0         Afghanistan   2017   36296.113
# 1      Afrique du Sud   2017   57009.756
# 2             Albanie   2017    2884.169
# 3             Algérie   2017   41389.189
# 4           Allemagne   2017   82658.409
# 5              Angola   2017   29816.766
# 6  Antigua-et-Barbuda   2017      95.426
# 7     Arabie saoudite   2017   33101.179
# 8           Argentine   2017   43937.140
# 9             Arménie   2017    2944.791
#
#    Disponibilité alimentaire (Kcal/personne/jour)
# 0                                          1871.0
# 1                                          2533.0
# 2                                          2203.0
# 3                                          2915.0
# 4                                          2461.0
# 5                                          2221.0
# 6                                          1635.0
# 7                                          2736.0
# 8                                          2239.0
# ...

# %%
# Il faut maintenant remettre la population à l'échélle 
Dispo_végétale['Population']=round((Dispo_végétale['Population']*1000),1)

# %%
Dispo_végétale.head()
# Out:
#              Zone  Année  Population  \
# 0     Afghanistan   2017  36296113.0
# 1  Afrique du Sud   2017  57009756.0
# 2         Albanie   2017   2884169.0
# 3         Algérie   2017  41389189.0
# 4       Allemagne   2017  82658409.0
#
#    Disponibilité alimentaire (Kcal/personne/jour)
# 0                                          1871.0
# 1                                          2533.0
# 2                                          2203.0
# 3                                          2915.0
# 4                                          2461.0

# %%
# Une fois la population à l'échelle nous pouvons la calculer par pays et l'intégérer à notre dataset principal
Dispo_Végétale_pays=(Dispo_végétale['Population']*Dispo_végétale['Disponibilité alimentaire (Kcal/personne/jour)'])

# %%
Dispo_végétale['Dispo_Végétale_pays']=Dispo_Végétale_pays
Dispo_végétale
# Out:
#                                        Zone  Année  Population  \
# 0                               Afghanistan   2017  36296113.0
# 1                            Afrique du Sud   2017  57009756.0
# 2                                   Albanie   2017   2884169.0
# 3                                   Algérie   2017  41389189.0
# 4                                 Allemagne   2017  82658409.0
# ..                                      ...    ...         ...
# 167  Venezuela (République bolivarienne du)   2017  29402484.0
# 168                                Viet Nam   2017  94600648.0
# 169                                   Yémen   2017  27834819.0
# 170                                  Zambie   2017  16853599.0
# 171                                Zimbabwe   2017  14236595.0
#
#      Disponibilité alimentaire (Kcal/personne/jour)  Dispo_Végétale_pays
# 0                                            1871.0         6.791003e+10
# ...

# %%
# Nous pouvons alors calculer la population totale, le nombre de calorie totale et par la suite population nourrie et la proportion qui en découle
Population_Totale=Dispo_végétale['Population'].sum()
kcal_Totale_végétale=Dispo_végétale['Dispo_Végétale_pays'].sum()
Kcal_min=2300

# %%
Population_nourrie_végétale=round((kcal_Totale_végétale/Kcal_min),1)
print(Population_nourrie_végétale)
# Out:
# 7504680092.0

# %%
print('Il y a',Population_nourrie_végétale,'personnes dans le monde qui peuvent être nourrie en raison de',Kcal_min,'kcal par jour et par personne avec une répartition égale des richesse végétales')
# Out:
# Il y a 7504680092.0 personnes dans le monde qui peuvent être nourrie en raison de 2300 kcal par jour et par personne avec une répartition égale des richesse végétales

# %%
Proportion_population_végétale=round((Population_nourrie_végétale/Population_Totale)*100,1)
Proportion_population_végétale
# Out:
# 102.9

# %%
print('Cela represente',Proportion_population_végétale,'% de la population qui serait nourrie')
# Out:
# Cela represente 102.9 % de la population qui serait nourrie

# %% [markdown]
# # IV)Proportion disponibilité Intérieur

# %%
# Nous allons d abord prendre les dataset qui nous interessse afin de pouvoir déterminer les résultats attendus
dispo_alimentaire.head()
# Out:
#           Zone                Produit   Origine  Aliments pour animaux  \
# 0  Afghanistan       Abats Comestible   animale                    NaN
# 1  Afghanistan        Agrumes, Autres  vegetale                    NaN
# 2  Afghanistan  Aliments pour enfants  vegetale                    NaN
# 3  Afghanistan                 Ananas  vegetale                    NaN
# 4  Afghanistan                Bananes  vegetale                    NaN
#
#    Autres Utilisations  Disponibilité alimentaire (Kcal/personne/jour)  \
# 0                  NaN                                             5.0
# 1                  NaN                                             1.0
# 2                  NaN                                             1.0
# 3                  NaN                                             0.0
# 4                  NaN                                             4.0
#
#    Disponibilité alimentaire en quantité (kg/personne/an)  \
# ...

# %%
dispo_alimentaire_intérieur=dispo_alimentaire[['Zone','Produit','Disponibilité intérieure','Nourriture','Aliments pour animaux','Autres Utilisations','Pertes']]
dispo_alimentaire_intérieur
# Out:
#                Zone                Produit  Disponibilité intérieure  \
# 0       Afghanistan       Abats Comestible                      53.0
# 1       Afghanistan        Agrumes, Autres                      41.0
# 2       Afghanistan  Aliments pour enfants                       2.0
# 3       Afghanistan                 Ananas                       0.0
# 4       Afghanistan                Bananes                      82.0
# ...             ...                    ...                       ...
# 15600  Îles Salomon       Viande de Suides                       3.0
# 15601  Îles Salomon    Viande de Volailles                       2.0
# 15602  Îles Salomon          Viande, Autre                       0.0
# 15603  Îles Salomon                    Vin                       0.0
# 15604  Îles Salomon         Épices, Autres                       0.0
#
#        Nourriture  Aliments pour animaux  Autres Utilisations  Pertes
# ...

# %%
### On groupe maintenant nos données en fonction des zones car nous voulons savoir ce qu'il se passe par Pays
dispoalim_intérieur=dispo_alimentaire_intérieur.groupby('Zone').sum()
dispoalim_intérieur
# Out:
# C:\Users\33682\AppData\Local\Temp\ipykernel_14812\1222712200.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dispoalim_intérieur=dispo_alimentaire_intérieur.groupby('Zone').sum()
#                        Disponibilité intérieure  Nourriture  \
# Zone
# Afghanistan                             13515.0     10735.0
# Afrique du Sud                          61256.0     29812.0
# Albanie                                  4758.0      3476.0
# Algérie                                 42630.0     31729.0
# Allemagne                              162275.0     79238.0
# ...                                         ...         ...
# Émirats arabes unis                     11850.0      6548.0
# Équateur                                18614.0      8574.0
# ...

# %%
# Nous pouvons maintenant établir les proportions que nous devions effectuer

Proportion_Nourriture=round((dispoalim_intérieur['Nourriture']/dispoalim_intérieur['Disponibilité intérieure']),2)*100
Proportion_Aliments_animaux=round((dispoalim_intérieur['Aliments pour animaux']/dispoalim_intérieur['Disponibilité intérieure']),2)*100
Proportion_autre_utilisations=round((dispoalim_intérieur['Autres Utilisations']/dispoalim_intérieur['Disponibilité intérieure']),2)*100
Proportion_Perte=round((dispoalim_intérieur['Pertes']/dispoalim_intérieur['Disponibilité intérieure']),2)*100

# %%
# Une fois les calculs effectués nous pouvons ajouter nos différents data à notre data principal
dispoalim_intérieur['Nourriture %']=Proportion_Nourriture
dispoalim_intérieur['Nourriture Animal %']=Proportion_Aliments_animaux
dispoalim_intérieur['Autres utilisation %']=Proportion_autre_utilisations
dispoalim_intérieur['Pertes %']=Proportion_Perte
dispoalim_intérieur
# Out:
#                        Disponibilité intérieure  Nourriture  \
# Zone
# Afghanistan                             13515.0     10735.0
# Afrique du Sud                          61256.0     29812.0
# Albanie                                  4758.0      3476.0
# Algérie                                 42630.0     31729.0
# Allemagne                              162275.0     79238.0
# ...                                         ...         ...
# Émirats arabes unis                     11850.0      6548.0
# Équateur                                18614.0      8574.0
# États-Unis d'Amérique                  777992.0    320889.0
# Éthiopie                                44014.0     33361.0
# Îles Salomon                              695.0       362.0
#
#                        Aliments pour animaux  Autres Utilisations  Pertes  \
# Zone
# Afghanistan                            768.0                415.0  1135.0
# Afrique du Sud                        5309.0                876.0  2193.0
# ...

# %%
# Nous pouvons aussi dissocier chaque demande séparement 
df_Nourriture=dispoalim_intérieur[['Disponibilité intérieure','Nourriture']]
df_Nourriture['Nourriture Pourcentage']=Proportion_Nourriture
df_Nourriture
# Out:
# C:\Users\33682\AppData\Local\Temp\ipykernel_14812\3845362849.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Nourriture['Nourriture Pourcentage']=Proportion_Nourriture
#                        Disponibilité intérieure  Nourriture  \
# Zone
# Afghanistan                             13515.0     10735.0
# Afrique du Sud                          61256.0     29812.0
# Albanie                                  4758.0      3476.0
# Algérie                                 42630.0     31729.0
# Allemagne                              162275.0     79238.0
# ...                                         ...         ...
# Émirats arabes unis                     11850.0      6548.0
# Équateur                                18614.0      8574.0
# ...

# %%
df_Aliments_animaux=dispoalim_intérieur[['Disponibilité intérieure','Aliments pour animaux']]
df_Aliments_animaux['Nourriture Animal Pourcentage']=Proportion_Aliments_animaux

df_Aliments_animaux
# Out:
# C:\Users\33682\AppData\Local\Temp\ipykernel_14812\2818398125.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Aliments_animaux['Nourriture Animal Pourcentage']=Proportion_Aliments_animaux
#                        Disponibilité intérieure  Aliments pour animaux  \
# Zone
# Afghanistan                             13515.0                  768.0
# Afrique du Sud                          61256.0                 5309.0
# Albanie                                  4758.0                  660.0
# Algérie                                 42630.0                 4352.0
# Allemagne                              162275.0                30209.0
# ...                                         ...                    ...
# ...

# %%
df_autre_utilisation=dispoalim_intérieur[['Disponibilité intérieure','Autres Utilisations']]
df_autre_utilisation['Autres_utilisation']=Proportion_autre_utilisations
df_autre_utilisation
# Out:
# C:\Users\33682\AppData\Local\Temp\ipykernel_36420\2972384070.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_autre_utilisation['Autres_utilisation']=Proportion_autre_utilisations
#                        Disponibilité intérieure  Autres Utilisations  \
# Zone
# Afghanistan                             13515.0                415.0
# Afrique du Sud                          61256.0                876.0
# Albanie                                  4758.0                174.0
# Algérie                                 42630.0               1707.0
# Allemagne                              162275.0               7711.0
# ...                                         ...                  ...
# ...

# %%
df_perte=dispoalim_intérieur[['Disponibilité intérieure','Pertes']]
df_perte['Pertes_alimentaire']=Proportion_Perte
df_perte
# Out:
# C:\Users\33682\AppData\Local\Temp\ipykernel_36420\3073266626.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_perte['Pertes_alimentaire']=Proportion_Perte
#                        Disponibilité intérieure  Pertes  Pertes_alimentaire
# Zone
# Afghanistan                             13515.0  1135.0                 8.0
# Afrique du Sud                          61256.0  2193.0                 4.0
# Albanie                                  4758.0   276.0                 6.0
# Algérie                                 42630.0  3753.0                 9.0
# Allemagne                              162275.0  3781.0                 2.0
# ...                                         ...     ...                 ...
# ...

# %% [markdown]
# # Le Manioc en Thaïlande

# %%
dispo_alimentaire.head()
# Out:
#           Zone                Produit   Origine  Aliments pour animaux  \
# 0  Afghanistan       Abats Comestible   animale                    NaN
# 1  Afghanistan        Agrumes, Autres  vegetale                    NaN
# 2  Afghanistan  Aliments pour enfants  vegetale                    NaN
# 3  Afghanistan                 Ananas  vegetale                    NaN
# 4  Afghanistan                Bananes  vegetale                    NaN
#
#    Autres Utilisations  Disponibilité alimentaire (Kcal/personne/jour)  \
# 0                  NaN                                             5.0
# 1                  NaN                                             1.0
# 2                  NaN                                             1.0
# 3                  NaN                                             0.0
# 4                  NaN                                             4.0
#
#    Disponibilité alimentaire en quantité (kg/personne/an)  \
# ...

# %%
# il faut maintenant filtrer les informations nécessaire 
data_manioc=dispo_alimentaire.loc[(dispo_alimentaire['Produit']=='Manioc') & (dispo_alimentaire['Zone']=='Thaïlande')].dropna(axis=1)

data_manioc.set_index('Zone')
# Out:
#           Produit   Origine  Aliments pour animaux  Autres Utilisations  \
# Zone
# Thaïlande  Manioc  vegetale                 1800.0               2081.0
#
#            Disponibilité alimentaire (Kcal/personne/jour)  \
# Zone
# Thaïlande                                            40.0
#
#            Disponibilité alimentaire en quantité (kg/personne/an)  \
# Zone
# Thaïlande                                               13.0
#
#            Disponibilité de matière grasse en quantité (g/personne/jour)  \
# Zone
# Thaïlande                                               0.05
#
#            Disponibilité de protéines en quantité (g/personne/jour)  \
# Zone
# Thaïlande                                               0.14
#
#            Disponibilité intérieure  Exportations - Quantité  \
# Zone
# Thaïlande                    6264.0                  25214.0
#
#            Importations - Quantité  Nourriture  Pertes  Production  \
# Zone
# ...

# %%
# Nous pouvons calculer la disponibilité intérieure de deux façons différentes
dispo_intérieurA=data_manioc['Aliments pour animaux']+data_manioc['Autres Utilisations']+data_manioc['Nourriture']+data_manioc['Pertes']+data_manioc['Traitement']
dispo_intérieurA
dispo_intérieurB=(data_manioc['Production']+data_manioc['Importations - Quantité']+data_manioc['Variation de stock'])-data_manioc['Exportations - Quantité']
dispo_intérieurB
# Out:
# 13809    6264.0
# dtype: float64

# %%
# Nous pouvons à présent faire notre calcule afin de déterminer la quantité exportée
Exportations_manioc=round((data_manioc['Exportations - Quantité']/data_manioc['Production']*100),2)
print (Exportations_manioc)
# Out:
# 13809    83.41
# dtype: float64

# %%
print('La Thaïlande exporte 83,41% de sa production de manioc' )
# Out:
# La Thaïlande exporte 83,41% de sa production de manioc

# %%
# Nous pouvons effectuer le même type de calcul pour savoir la représentation du manioc dans l'alimentation des Thaïlandais et de leurs animaux

Nourriture_manioc= round((data_manioc['Nourriture']/data_manioc['Production']*100),2)
Autre_manioc=round((data_manioc['Autres Utilisations']/data_manioc['Production']*100),2)
Dispo_inte_manioc=round((data_manioc['Disponibilité intérieure']/data_manioc['Production']*100),2)
Pertes_manioc=round((data_manioc['Pertes']/data_manioc['Production']*100),2)
Animal_manioc=round((data_manioc['Aliments pour animaux']/data_manioc['Production']*100),2)

# %%
print(Nourriture_manioc)
# Out:
# 13809    2.88
# dtype: float64

# %%
print(Animal_manioc)
# Out:
# 13809    5.95
# dtype: float64

# %%
print('La production de manioc représente respectivement 2,88 % de l alimention de la population et 5,95 % de l alimentation animale')
# Out:
# La production de manioc représente respectivement 2,88 % de l alimention de la population et 5,95 % de l alimentation animale

# %%
# Nous pouvons effectuer le même calcul en fonction de la disponibilité intérieure
Nourriture_maniocI= round((data_manioc['Nourriture']/data_manioc['Disponibilité intérieure']*100),2)
Autre_maniocI=round((data_manioc['Autres Utilisations']/data_manioc['Disponibilité intérieure']*100),2)
Pertes_maniocI=round((data_manioc['Pertes']/data_manioc['Disponibilité intérieure']*100),2)
Animal_maniocI=round((data_manioc['Aliments pour animaux']/data_manioc['Disponibilité intérieure']*100),2)

# %%
df_manioc= pd.DataFrame({'%':['Nourriture_maniocI','Autre_maniocI','Pertes_maniocI','Animal_maniocI'],
                        'Résultat':[13.90,33.22,24.12,28.73]})
df_manioc
# Out:
#                     %  Résultat
# 0  Nourriture_maniocI     13.90
# 1       Autre_maniocI     33.22
# 2      Pertes_maniocI     24.12
# 3      Animal_maniocI     28.73

# %%
df_manioc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   %         4 non-null      object
#  1   Résultat  4 non-null      float64
# dtypes: float64(1), object(1)
# memory usage: 192.0+ bytes

# %%
plt.pie(x=df_manioc['Résultat'], labels=df_manioc['%'],labeldistance=1.2,shadow=True,rotatelabels=False,autopct='%.2f%%')
plt.title('Répartition du manioc sur la disponibilité intérieure')
# Out:
# Text(0.5, 1.0, 'Répartition du manioc sur la disponibilité intérieure')

# %%
# Nous pouvons aussi déterminer la population en sous-nutrition et sa corrélation avec la quantité de manioc accordé à la population
sous_nutrition_2013 = sous_nutrition.loc[sous_nutrition['Année']=='2012-2014']
population_2013 = population.loc[population['Année']== 2013]

# %%
# Il faut que nous fassions une jointure entre nos deux tables afin de continuer notre raisonnement
différence_2013=pd.merge(population_2013,sous_nutrition_2013,on=['Zone','Zone'],how= 'inner')

# %%
# On renomme et élimine les colonnes dont nous n'avons pas besoin
différence_2013=différence_2013.rename(columns={'Année_x':'Année','Valeur_x':'Population','Valeur_y':'population_sous_nourries'})
différence_2013=différence_2013.drop(columns='Année_y')
différence_2013
# Out:
#                                        Zone  Année  Population  \
# 0                               Afghanistan   2013   32269.589
# 1                            Afrique du Sud   2013   53687.121
# 2                                   Albanie   2013    2903.790
# 3                                   Algérie   2013   38140.133
# 4                                 Allemagne   2013   81174.367
# ..                                      ...    ...         ...
# 198  Venezuela (République bolivarienne du)   2013   29781.040
# 199                                Viet Nam   2013   90752.592
# 200                                   Yémen   2013   25147.109
# 201                                  Zambie   2013   14926.544
# 202                                Zimbabwe   2013   13350.373
#
#     population_sous_nourries
# 0                        8.6
# 1                        2.2
# 2                        0.1
# 3                        1.3
# 4                        NaN
# ...

# %%
# On spécifie le faite que la Zine qui nous interesse est la thaïlande
différence_Thaïlande=différence_2013.loc[(différence_2013['Zone']=='Thaïlande')]
différence_Thaïlande
# Out:
#           Zone  Année  Population population_sous_nourries
# 185  Thaïlande   2013   68144.518                      6.2

# %%
différence_Thaïlande['Population']=round((différence_Thaïlande['Population']/1000),2)
différence_Thaïlande['population_sous_nourries']=différence_Thaïlande['population_sous_nourries'].astype(float,errors='raise')
différence_Thaïlande
# Out:
# C:\Users\33682\AppData\Local\Temp\ipykernel_36420\2718847277.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   différence_Thaïlande['Population']=round((différence_Thaïlande['Population']/1000),2)
# C:\Users\33682\AppData\Local\Temp\ipykernel_36420\2718847277.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   différence_Thaïlande['population_sous_nourries']=différence_Thaïlande['population_sous_nourries'].astype(float,errors='raise')
# ...

# %%
# On peut déterminer à présent la proportion de la population sous nourries
Population_sous_nourrie_Thaï=round((différence_Thaïlande['population_sous_nourries']/différence_Thaïlande['Population']*100),2)
Population_sous_nourrie_Thaï
# Out:
# 185    9.1
# dtype: float64

# %%
print("On est estime à 9,1 % la population qui serait en sous-nutrition en Thaïlande")
# Out:
# On est estime à 9,1 % la population qui serait en sous-nutrition en Thaïlande

# %%
# A présent nous pouvons déterminer la population qu'il est possible de nourrir 
kcal_min=2300
pop_Thaïlande=68144518
pop_sous_nourrie_Thaï=6200000
kcal_thaï=40
kcal_Population=pop_Thaïlande*kcal_thaï
population_nourrie_manioc=round((kcal_Population/kcal_min),2)
population_nourrie_manioc
# Out:
# 1185122.05

# %%
print('Avec une base moyenne de 2300Kcal nous pouvons nourrir',population_nourrie_manioc,'personnes soit 1,74% de la population de la Thaïlande soit 19% de la population en état de sous nutrition')
# Out:
# Avec une base moyenne de 2300Kcal nous pouvons nourrir 1185122.05 personnes soit 1,74% de la population de la Thaïlande soit 19% de la population en état de sous nutrition

# %%
# Nous pouvons effectuer le même calcul sur la quantité de nourriture mais aussi la quantité exportée par an en Thaïlande
kcal_manioc=1570
Tonne_manioc_Nourriture=871000*1000
Tonne_manioc_Exportation=25214000*1000
Kcal_Tonne_Nourriture=Tonne_manioc_Nourriture*kcal_manioc
Kcal_Tonne_Exportation=Tonne_manioc_Exportation*kcal_manioc
Personne_Nourriture=round((Kcal_Tonne_Nourriture/kcal_min)/365,2)
Personne_Exportation=round((Kcal_Tonne_Exportation/kcal_min)/365,2)

# %%
#On peut maintenant calculer la proportion
Proportion_manioc_N=round((Personne_Nourriture/pop_Thaïlande)*100,2)
Proportion_manioc_E=round((Personne_Exportation/pop_Thaïlande)*100,2)

# %%
print('La Thaïlande utilise  871000 tonnes de manioc pour la nourriture de la population ce qui represente',Proportion_manioc_N,'% de la population')
print('Sur une année la Thaïlande exporte 25214000 tonnes de manioc ce qui pourrait alimenter ',Proportion_manioc_E,'% de la population thaïlandaise')
# Out:
# La Thaïlande utilise  871000 tonnes de manioc pour la nourriture de la population ce qui represente 2.39 % de la population
# Sur une année la Thaïlande exporte 25214000 tonnes de manioc ce qui pourrait alimenter  69.2 % de la population thaïlandaise

# %% [markdown]
# # Utilisation des céréales

# %%
dispo_céréale=pd.read_csv('Dispo_céréales.csv')
dispo_céréale.head(15)
# Out:
#                         Domaine         Zone  \
# 0   Bilans Alimentaires (2010-)  Afghanistan
# 1   Bilans Alimentaires (2010-)  Afghanistan
# 2   Bilans Alimentaires (2010-)  Afghanistan
# 3   Bilans Alimentaires (2010-)  Afghanistan
# 4   Bilans Alimentaires (2010-)  Afghanistan
# 5   Bilans Alimentaires (2010-)  Afghanistan
# 6   Bilans Alimentaires (2010-)  Afghanistan
# 7   Bilans Alimentaires (2010-)  Afghanistan
# 8   Bilans Alimentaires (2010-)  Afghanistan
# 9   Bilans Alimentaires (2010-)  Afghanistan
# 10  Bilans Alimentaires (2010-)  Afghanistan
# 11  Bilans Alimentaires (2010-)  Afghanistan
# 12  Bilans Alimentaires (2010-)  Afghanistan
# 13  Bilans Alimentaires (2010-)  Afghanistan
# 14  Bilans Alimentaires (2010-)  Afghanistan
#
#                                   Élément          Produit  Année  \
# 0                              Production  Blé et produits   2017
# 1                 Importations - Quantité  Blé et produits   2017
# ...

# %%
dispo_céréale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18414 entries, 0 to 18413
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Domaine  18414 non-null  object
#  1   Zone     18414 non-null  object
#  2   Élément  18414 non-null  object
#  3   Produit  18414 non-null  object
#  4   Année    18414 non-null  int64
#  5   Unité    12478 non-null  object
#  6   Valeur   12478 non-null  float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 1007.1+ KB

# %%
# On étudie les données qui vont être intéressante 
dispo_céréale=dispo_céréale.loc[dispo_céréale['Valeur'].notnull()]
dispo_céréale
# Out:
#                            Domaine         Zone                   Élément  \
# 0      Bilans Alimentaires (2010-)  Afghanistan                Production
# 1      Bilans Alimentaires (2010-)  Afghanistan   Importations - Quantité
# 2      Bilans Alimentaires (2010-)  Afghanistan        Variation de stock
# 3      Bilans Alimentaires (2010-)  Afghanistan   Exportations - Quantité
# 4      Bilans Alimentaires (2010-)  Afghanistan  Disponibilité intérieure
# ...                            ...          ...                       ...
# 18406  Bilans Alimentaires (2010-)     Zimbabwe   Exportations - Quantité
# 18407  Bilans Alimentaires (2010-)     Zimbabwe  Disponibilité intérieure
# 18408  Bilans Alimentaires (2010-)     Zimbabwe     Aliments pour animaux
# 18410  Bilans Alimentaires (2010-)     Zimbabwe                    Pertes
# 18413  Bilans Alimentaires (2010-)     Zimbabwe                Nourriture
#
#                 Produit  Année               Unité  Valeur
# ...

# %%
dispo_céréale=dispo_céréale.drop(columns=['Domaine','Année'])

dispo_céréale
# Out:
#               Zone                   Élément           Produit  \
# 0      Afghanistan                Production   Blé et produits
# 1      Afghanistan   Importations - Quantité   Blé et produits
# 2      Afghanistan        Variation de stock   Blé et produits
# 3      Afghanistan   Exportations - Quantité   Blé et produits
# 4      Afghanistan  Disponibilité intérieure   Blé et produits
# ...            ...                       ...               ...
# 18406     Zimbabwe   Exportations - Quantité  Céréales, Autres
# 18407     Zimbabwe  Disponibilité intérieure  Céréales, Autres
# 18408     Zimbabwe     Aliments pour animaux  Céréales, Autres
# 18410     Zimbabwe                    Pertes  Céréales, Autres
# 18413     Zimbabwe                Nourriture  Céréales, Autres
#
#                     Unité  Valeur
# 0      Milliers de tonnes  4281.0
# 1      Milliers de tonnes  3080.0
# 2      Milliers de tonnes   208.0
# 3      Milliers de tonnes     2.0
# ...

# %%
dispo_céréale['Produit'].unique()
# Out:
# array(['Blé et produits', 'Riz et produits', 'Orge et produits',
#        'Maïs et produits', 'Seigle et produits', 'Avoine',
#        'Millet et produits', 'Sorgho et produits', 'Céréales, Autres'],
#       dtype=object)

# %%
dispo_alimentaire_céréale=pd.pivot_table(data=dispo_céréale,index=['Élément'],aggfunc="sum")
dispo_alimentaire_céréale
# Out:
# C:\Users\33682\AppData\Local\Temp\ipykernel_36420\2518556581.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dispo_alimentaire_céréale=pd.pivot_table(data=dispo_céréale,index=['Élément'],aggfunc="sum")
#                                           Valeur
# Élément
# Aliments pour animaux                   937061.0
# Autres utilisations (non alimentaire)   279690.0
# Disponibilité intérieure               2850431.0
# Exportations - Quantité                 542973.0
# Importations - Quantité                 520557.0
# Nourriture                             1311773.0
# Pertes                                  135531.0
# Production                             2961046.0
# Semences                                 80176.0
# Traitement                              110296.0
# ...

# %%
# Nous allons créer les différentes variables afin d'effectuer les proportions utiliséés
Céréale_animaux = 937061
Céréale_non_alimentaire = 279690
Céréale_exportations = 542973
Céréale_importations = 520557
Céréale_nourriture = 1311773
Céréale_pertes= 135531
Céréale_production= 2961046
Céréale_semences= 80176 
Céréale_variation_stock=88193 
Céréale_traitement = 110296

# %%
print(Céréale_animaux)
# Out:
# 937061

# %%
df_Nourriture=round((Céréale_nourriture/Céréale_production)*100,2)
df_Nourriture
print('Il y a 45,95% de la production de céréale qui est utilisé pour la nourriture')
# Out:
# Il y a 45,95% de la production de céréale qui est utilisé pour la nourriture

# %%
df_Animaux=round((Céréale_animaux/Céréale_production)*100,2)
df_Animaux
print('La production de céréale animalière correspond à ',df_Animaux,'% de la production mondiale')
# Out:
# La production de céréale animalière correspond à  31.65 % de la production mondiale

# %%
df_Autres=round((Céréale_non_alimentaire/Céréale_production)*100,2)
df_Autres
print('La production non alimentaire de céréale  correspond à',df_Autres,'% du total mondial')
# Out:
# La production non alimentaire de céréale  correspond à 9.45 % du total mondial

# %%
df_Pertes=round((Céréale_pertes/Céréale_production)*100,2)
df_Pertes
print('Les pertes en céréales sont évaluées à',df_Pertes,'% de la production mondiale')
# Out:
# Les pertes en céréales sont évaluées à 4.58 % de la production mondiale

# %%
df_Semences=round((Céréale_semences/Céréale_production)*100,2)
df_Semences
print('Les semences correspondent à',df_Semences,'% de la production de céréale')
# Out:
# Les semences correspondent à 2.71 % de la production de céréale

# %%
df_Traitement=round((Céréale_traitement/Céréale_production)*100,2)
df_Traitement
print('Le traitement céréalier correspond à ',df_Traitement,'% de la production mondiale')
# Out:
# Le traitement céréalier correspond à  3.72 % de la production mondiale

# %%
df_Exportation=round((Céréale_exportations/Céréale_production)*100,2)
df_Exportation
print('Les exportations correspondent à',df_Exportation,'% de la production mondialede céréale')
# Out:
# Les exportations correspondent à 18.34 % de la production mondialede céréale

# %%
new_df1= pd.DataFrame({'%': [df_Nourriture ,df_Animaux, df_Autres,df_Traitement,df_Semences,df_Pertes]}, 
index=['Nourriture%', 'Animaux%', 'Autres%','Pertes%','Traitement%','Semences%'])
new_df1
# Out:
#                  %
# Nourriture%  44.30
# Animaux%     31.65
# Autres%       9.45
# Pertes%       3.72
# Traitement%   2.71
# Semences%     4.58

# %%
new_df1.plot.pie(y='%',figsize=(8, 8),autopct='%.2f%%',shadow=True, title='Répartition des Céréales')
# Out:
# <AxesSubplot: title={'center': 'Répartition des Céréales'}, ylabel='%'>

# %% [markdown]
# # Les demandes de Mélanie

# %% [markdown]
# # I) Les pays Bénéficiaire d'aide

# %%
aide_pays=aide_alimentaire
aide_pays=aide_pays.loc[aide_pays['Année'].notnull()]
aide_pays.head(10)
# Out:
#   Pays bénéficiaire  Année                   Produit  Valeur
# 0       Afghanistan   2013       Autres non-céréales     682
# 1       Afghanistan   2014       Autres non-céréales     335
# 2       Afghanistan   2013              Blé et Farin   39224
# 3       Afghanistan   2014              Blé et Farin   15160
# 4       Afghanistan   2013                  Céréales   40504
# 5       Afghanistan   2014                  Céréales   15989
# 6       Afghanistan   2013        Fruits secs, total      85
# 7       Afghanistan   2013          Huiles végétales   11087
# 8       Afghanistan   2014          Huiles végétales    8185
# 9       Afghanistan   2013  Légumineuses Sèches,Tot.   11761

# %%
# Nous pouvons maintenant calculer les pays qui bénéficie le plus d'aide alimentaire

df_aide_pays=aide_pays.groupby('Pays bénéficiaire')[['Valeur']].sum()

df_aide_pays.sort_values(by='Valeur', ascending=False)
# Out:
#                                   Valeur
# Pays bénéficiaire
# République arabe syrienne        1858943
# Éthiopie                         1381294
# Yémen                            1206484
# Soudan du Sud                     695248
# Soudan                            669784
# ...                                  ...
# Égypte                              1122
# Vanuatu                              802
# Timor-Leste                          116
# Géorgie                               70
# Bolivie (État plurinational de)        6
#
# [76 rows x 1 columns]

# %%
# On réorganise notre dataframe et on rajoute notre nouvelle donnée 

df_aide_année=pd.pivot_table(data=aide_pays, index='Pays bénéficiaire', columns= 'Année', aggfunc=sum)

# On remplace les données Nan afin de rendre plus lisible nos données 

df_aide_année=df_aide_année['Valeur'].fillna(0)
df_aide_année['Total_Tonne']=df_aide_année.sum(axis=1)
df_aide_année
# Out:
# C:\Users\33682\AppData\Local\Temp\ipykernel_36420\2454993973.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_aide_année=pd.pivot_table(data=aide_pays, index='Pays bénéficiaire', columns= 'Année', aggfunc=sum)
# Année                  2013      2014      2015    2016  Total_Tonne
# Pays bénéficiaire
# Afghanistan        128238.0   57214.0       0.0     0.0     185452.0
# Algérie             35234.0   18980.0   17424.0  9476.0      81114.0
# Angola               5000.0      14.0       0.0     0.0       5014.0
# Bangladesh         131018.0  194628.0   22542.0     0.0     348188.0
# Bhoutan              1724.0     146.0     578.0   218.0       2666.0
# ...                     ...       ...       ...     ...          ...
# Zambie                328.0    2698.0       0.0     0.0       3026.0
# ...

# %%
# Distribution d'aide alimentaire entre 2013 et 2016
df_année=aide_pays.groupby('Année')[['Valeur']].sum()

df_année
# Out:
#         Valeur
# Année
# 2013   4165674
# 2014   3939152
# 2015   2187507
# 2016    743568

# %%
# Distribution d'aide alimentaire en Tonne par Produit 
df_produit=aide_alimentaire.groupby('Produit')[['Valeur']].sum()


print('Les céréales sont le produits dont l aide alimentaire est la plus importante')
df_produit.sort_values(by='Valeur', ascending=False)
# Out:
# Les céréales sont le produits dont l aide alimentaire est la plus importante
#                            Valeur
# Produit
# Céréales                  4256884
# Blé et Farin              1781515
# Non-céréales              1261513
# Céréales Secondaires      1166565
# Riz, total                 742418
# Légumineuses Sèches,Tot.   737398
# Mélanges et préparations   425839
# Huiles végétales           344973
# BulgurFarEnt               140547
# Sucre, total               101014
# Autres non-céréales         48871
# Lait, total                 12478
# Fruits secs, total           9386
# Poiss&produi                 6397
# Viande Total                   53
# Graisses Com                   50

# %% [markdown]
#   # II) Dispo alimentaire 2017

# %%
# Nous allons utilisé les fichiers de dispo_alimentaire et de population

# %%
dispo_alimentaire.head()
dispo_alimentaire=dispo_alimentaire

# %%
population_2017.head()
# Out:
#               Zone  Année  Population
# 4      Afghanistan   2017   36296.113
# 10  Afrique du Sud   2017   57009.756
# 16         Albanie   2017    2884.169
# 22         Algérie   2017   41389.189
# 28       Allemagne   2017   82658.409

# %%
# On épure notre dataframe afin de continuer l'analyse

dispo_alimentaire_2017=dispo_alimentaire.drop(columns=['Disponibilité intérieure',
                                                       'Exportations - Quantité',
                                                       'Importations - Quantité','Nourriture',
                                                       'Pertes','Production','Semences','Traitement',
                                                       'Variation de stock','Produit','Origine',
                                                       'Aliments pour animaux','Autres Utilisations'])

dispo_alimentaire_2017=pd.pivot_table(data=dispo_alimentaire_2017, index='Zone', aggfunc=sum)
dispo_alimentaire_2017
# Out:
#                        Disponibilité alimentaire (Kcal/personne/jour)  \
# Zone
# Afghanistan                                                    2087.0
# Afrique du Sud                                                 3020.0
# Albanie                                                        3188.0
# Algérie                                                        3293.0
# Allemagne                                                      3503.0
# ...                                                               ...
# Émirats arabes unis                                            3275.0
# Équateur                                                       2346.0
# États-Unis d'Amérique                                          3682.0
# Éthiopie                                                       2129.0
# Îles Salomon                                                   2383.0
#
#                        Disponibilité alimentaire en quantité (kg/personne/an)  \
# Zone
# ...

# %%
# on fait une jointure entre nos deux dataframe et on ramene la population en million de personne

df_dispo_2017=pd.merge(population_2017,dispo_alimentaire_2017,on='Zone',how='inner')
df_dispo_2017=df_dispo_2017.rename(columns={'Valeur':'Population'})
df_dispo_2017['Population']=(df_dispo_2017['Population']*1000)
df_dispo_2017
# Out:
#                                        Zone  Année  Population  \
# 0                               Afghanistan   2017  36296113.0
# 1                            Afrique du Sud   2017  57009756.0
# 2                                   Albanie   2017   2884169.0
# 3                                   Algérie   2017  41389189.0
# 4                                 Allemagne   2017  82658409.0
# ..                                      ...    ...         ...
# 167  Venezuela (République bolivarienne du)   2017  29402484.0
# 168                                Viet Nam   2017  94600648.0
# 169                                   Yémen   2017  27834819.0
# 170                                  Zambie   2017  16853599.0
# 171                                Zimbabwe   2017  14236595.0
#
#      Disponibilité alimentaire (Kcal/personne/jour)  \
# 0                                            2087.0
# 1                                            3020.0
# ...

# %%
# Classement des pays qui ont la plus faible disponibilité alimentaire en KCAL
dispo_kcal2017=df_dispo_2017.drop(columns=['Disponibilité alimentaire en quantité (kg/personne/an)',
                                           'Disponibilité de matière grasse en quantité (g/personne/jour)',
                                           'Disponibilité de protéines en quantité (g/personne/jour)'])
dispo_kcal2017=dispo_kcal2017.sort_values(by='Disponibilité alimentaire (Kcal/personne/jour)',ascending=True,ignore_index=True)
dispo_kcal2017.head(10)
# Out:
#                                          Zone  Année   Population  \
# 0                   République centrafricaine   2017    4596023.0
# 1                                      Zambie   2017   16853599.0
# 2                                  Madagascar   2017   25570512.0
# 3                                 Afghanistan   2017   36296113.0
# 4                                       Haïti   2017   10982366.0
# 5  République populaire démocratique de Corée   2017   25429825.0
# 6                                       Tchad   2017   15016753.0
# 7                                    Zimbabwe   2017   14236595.0
# 8                                     Ouganda   2017   41166588.0
# 9                                    Éthiopie   2017  106399924.0
#
#    Disponibilité alimentaire (Kcal/personne/jour)
# 0                                          1879.0
# 1                                          1924.0
# 2                                          2056.0
# ...

# %%
# Classement des pays qui ont la plus forte disponibilité alimentaire en KCAL
dispo_kcal2017=dispo_kcal2017.sort_values(by='Disponibilité alimentaire (Kcal/personne/jour)',ascending=False,ignore_index=True)
dispo_kcal2017.head(10)
# Out:
#                     Zone  Année   Population  \
# 0               Autriche   2017    8819901.0
# 1               Belgique   2017   11419748.0
# 2                Turquie   2017   81116450.0
# 3  États-Unis d'Amérique   2017  325084756.0
# 4                 Israël   2017    8243848.0
# 5                Irlande   2017    4753279.0
# 6                 Italie   2017   60673701.0
# 7             Luxembourg   2017     591910.0
# 8                 Égypte   2017   96442591.0
# 9              Allemagne   2017   82658409.0
#
#    Disponibilité alimentaire (Kcal/personne/jour)
# 0                                          3770.0
# 1                                          3737.0
# 2                                          3708.0
# 3                                          3682.0
# 4                                          3610.0
# 5                                          3602.0
# 6                                          3578.0
# 7                                          3540.0
# ...

# %%
# Classement des pays ayant la disponibilité alimentaire la plus forte en quantité

dispo_kg_2017=df_dispo_2017.drop(columns=['Disponibilité alimentaire (Kcal/personne/jour)',
                                          'Disponibilité de matière grasse en quantité (g/personne/jour)',
                                          'Disponibilité de protéines en quantité (g/personne/jour)'])

dispo_kg_2017=dispo_kg_2017.sort_values(by='Disponibilité alimentaire en quantité (kg/personne/an)',ascending=False,ignore_index=True)
dispo_kg_2017.head(10)
# Out:
#          Zone  Année  Population  \
# 0  Monténégro   2017    627563.0
# 1  Luxembourg   2017    591910.0
# 2     Irlande   2017   4753279.0
# 3     Albanie   2017   2884169.0
# 4    Finlande   2017   5511371.0
# 5       Grèce   2017  10569450.0
# 6    Pays-Bas   2017  17021347.0
# 7    Autriche   2017   8819901.0
# 8    Lituanie   2017   2845414.0
# 9    Danemark   2017   5732274.0
#
#    Disponibilité alimentaire en quantité (kg/personne/an)
# 0                                            1210.41
# 1                                            1150.66
# 2                                            1150.15
# 3                                            1095.54
# 4                                            1093.77
# 5                                            1070.90
# 6                                            1069.22
# 7                                            1069.20
# 8                                            1050.07
# 9                                            1031.04

# %%
# Classement des pays ayant la disponibilité alimentaire la plus faible en quantité

dispo_kg_2017=dispo_kg_2017.sort_values(by='Disponibilité alimentaire en quantité (kg/personne/an)',ascending=True,ignore_index=True)
dispo_kg_2017.head(10)
# Out:
#             Zone  Année   Population  \
# 0          Tchad   2017   15016753.0
# 1       Zimbabwe   2017   14236595.0
# 2         Zambie   2017   16853599.0
# 3    Afghanistan   2017   36296113.0
# 4       Éthiopie   2017  106399924.0
# 5  Guinée-Bissau   2017    1828145.0
# 6     Bangladesh   2017  159685424.0
# 7    Timor-Leste   2017    1243258.0
# 8          Yémen   2017   27834819.0
# 9        Sénégal   2017   15419355.0
#
#    Disponibilité alimentaire en quantité (kg/personne/an)
# 0                                             319.45
# 1                                             336.59
# 2                                             350.12
# 3                                             351.41
# 4                                             354.55
# 5                                             358.48
# 6                                             364.54
# 7                                             369.10
# 8                                             375.41
# ...

# %%
# Classement des pays ayant la disponibilité de matière grasse la plus faible

dispo_matiere_grasse=df_dispo_2017.drop(columns=['Disponibilité alimentaire (Kcal/personne/jour)',
                                                 'Disponibilité alimentaire en quantité (kg/personne/an)',
                                                 'Disponibilité de protéines en quantité (g/personne/jour)'])

dispo_matiere_grasse=dispo_matiere_grasse.sort_values(by='Disponibilité de matière grasse en quantité (g/personne/jour)', ascending=True,ignore_index=True)
dispo_matiere_grasse.head(10)
# Out:
#                                          Zone  Année   Population  \
# 0                                      Rwanda   2017   11980961.0
# 1                                  Madagascar   2017   25570512.0
# 2                                    Éthiopie   2017  106399924.0
# 3                                  Bangladesh   2017  159685424.0
# 4                                     Lesotho   2017    2091534.0
# 5                                 Afghanistan   2017   36296113.0
# 6                                    Cambodge   2017   16009409.0
# 7  République populaire démocratique de Corée   2017   25429825.0
# 8       République démocratique populaire lao   2017    6953035.0
# 9                                      Malawi   2017   17670196.0
#
#    Disponibilité de matière grasse en quantité (g/personne/jour)
# 0                                              23.77
# 1                                              24.49
# 2                                              25.89
# ...

# %%
# Classement des pays ayant la disponibilité de matière grasse la plus forte

dispo_matiere_grasse=dispo_matiere_grasse.sort_values(by='Disponibilité de matière grasse en quantité (g/personne/jour)', ascending=False,ignore_index=True)
dispo_matiere_grasse.head(10)
# Out:
#                     Zone  Année   Population  \
# 0               Autriche   2017    8819901.0
# 1               Belgique   2017   11419748.0
# 2  États-Unis d'Amérique   2017  325084756.0
# 3                 France   2017   64842509.0
# 4                 Italie   2017   60673701.0
# 5                 Suisse   2017    8455804.0
# 6                 Israël   2017    8243848.0
# 7                Islande   2017     334393.0
# 8              Australie   2017   24584620.0
# 9                Norvège   2017    5296326.0
#
#    Disponibilité de matière grasse en quantité (g/personne/jour)
# 0                                             170.44
# 1                                             161.95
# 2                                             161.37
# 3                                             159.15
# 4                                             154.69
# 5                                             153.35
# 6                                             151.39
# ...

# %%
# Classement des pays dont la la quantité de protéines est la plus faible

dispo_protéïne=df_dispo_2017.drop(columns=['Disponibilité alimentaire (Kcal/personne/jour)',
                                           'Disponibilité alimentaire en quantité (kg/personne/an)',
                                           'Disponibilité de matière grasse en quantité (g/personne/jour)']
                                 )
dispo_protéïne=dispo_protéïne.sort_values(by='Disponibilité de protéines en quantité (g/personne/jour)',ascending=True,ignore_index=True)
dispo_protéïne.head(10)
# Out:
#                         Zone  Année  Population  \
# 0                    Libéria   2017   4702226.0
# 1              Guinée-Bissau   2017   1828145.0
# 2                 Mozambique   2017  28649018.0
# 3  République centrafricaine   2017   4596023.0
# 4                 Madagascar   2017  25570512.0
# 5                      Haïti   2017  10982366.0
# 6                   Zimbabwe   2017  14236595.0
# 7                      Congo   2017   5110695.0
# 8                    Ouganda   2017  41166588.0
# 9       Sao Tomé-et-Principe   2017    207089.0
#
#    Disponibilité de protéines en quantité (g/personne/jour)
# 0                                              37.66
# 1                                              44.05
# 2                                              45.68
# 3                                              46.04
# 4                                              46.69
# 5                                              47.70
# ...

# %%
# Classement des pays dont la la quantité de protéines est la plus forte

dispo_protéïne=dispo_protéïne.sort_values(by='Disponibilité de protéines en quantité (g/personne/jour)',ascending=False,ignore_index=True)
dispo_protéïne.head(10)
# Out:
#                        Zone  Année  Population  \
# 0                   Islande   2017    334393.0
# 1  Chine - RAS de Hong-Kong   2017   7306322.0
# 2                    Israël   2017   8243848.0
# 3                  Lituanie   2017   2845414.0
# 4                  Maldives   2017    496402.0
# 5                  Finlande   2017   5511371.0
# 6                Luxembourg   2017    591910.0
# 7                Monténégro   2017    627563.0
# 8                  Pays-Bas   2017  17021347.0
# 9                   Albanie   2017   2884169.0
#
#    Disponibilité de protéines en quantité (g/personne/jour)
# 0                                             133.06
# 1                                             129.07
# 2                                             128.00
# 3                                             124.36
# 4                                             122.32
# 5                                             117.56
# 6                                             113.64
# ...

# %% [markdown]
# # III) Proportion personnes sous alimentés 2017

# %%
# Classement des Pays ou la Proportion de la population en sous-nutrition est la plus élevée
différence_2017=différence_2017.sort_values(by= 'proportion_2017',ascending= False,ignore_index=True)
différence_2017.head(10)
# Out:
#                                          Zone  Année  Population  \
# 0                                       Haïti   2017        11.0
# 1  République populaire démocratique de Corée   2017        25.4
# 2                                  Madagascar   2017        25.6
# 3                                     Libéria   2017         4.7
# 4                                     Lesotho   2017         2.1
# 5                                       Tchad   2017        15.0
# 6                                      Rwanda   2017        12.0
# 7                                 Timor-Leste   2017         1.2
# 8                                  Mozambique   2017        28.6
# 9                                 Afghanistan   2017        36.3
#
#    Population_sous_nourries  proportion_2017
# 0                       5.3            48.18
# 1                      12.0            47.24
# 2                      10.5            41.02
# 3                       1.8            38.30
# ...
